# %% [markdown]
# # Project - Deep Learning

# %%
# !wget https://www.lamsade.dauphine.fr/~cazenave/project2022.zip
# !unzip project2022.zip
# Out:
# --2022-10-18 08:19:52--  https://www.lamsade.dauphine.fr/~cazenave/project2022.zip
# Resolving www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)... 193.48.71.250
# Connecting to www.lamsade.dauphine.fr (www.lamsade.dauphine.fr)|193.48.71.250|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 138784129 (132M) [application/zip]
# Saving to: ‘project2022.zip’
#
# project2022.zip     100%[===================>] 132.35M  14.8MB/s    in 10s
#
# 2022-10-18 08:20:04 (12.9 MB/s) - ‘project2022.zip’ saved [138784129/138784129]
#
# Archive:  project2022.zip
#   inflating: Board.h
#   inflating: Game.h
#   inflating: Rzone.h
#   inflating: compile.sh
#   inflating: compileMAC.sh
#   inflating: games.data
#   inflating: golois.cpp
#   inflating: golois.cpython-310-x86_64-linux-gnu.so
#   inflating: golois.cpython-37m-x86_64-linux-gnu.so
#   inflating: golois.cpython-38-x86_64-linux-gnu.so
#   inflating: golois.py
#   inflating: importGolois.ipynb
#   inflating: zip.sh

# %%
import tensorflow as tf
import tensorflow.keras as keras
import numpy as np
from tensorflow.keras import layers 
from tensorflow.keras import regularizers
import gc

import golois

# %% [markdown]
# ## Week 0 - First attempt:

# %% [markdown]
# "Multiple Inputs/Outputs" model

# %%
planes = 31
moves = 361
N = 10000
epochs = 20
batch = 128
filters = 32

input_data = np.random.randint(2, size=(N, 19, 19, planes))
input_data = input_data.astype ('float32')

policy = np.random.randint(moves, size=(N,))
policy = keras.utils.to_categorical (policy)

value = np.random.randint(2, size=(N,))
value = value.astype ('float32')

end = np.random.randint(2, size=(N, 19, 19, 2))
end = end.astype ('float32')

groups = np.zeros((N, 19, 19, 1))
groups = groups.astype ('float32')

print ("getValidation", flush = True)
golois.getValidation (input_data, policy, value, end)
# Out:
# getValidation

# %%
input = keras.Input(shape=(19, 19, planes), name='board')
x = layers.Conv2D(32, 3, activation='relu', padding='same')(input)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)
x = layers.Conv2D(32, 3, activation='relu', padding='same')(x)

policy_head = layers.Conv2D(1, 1, activation='swish', padding='same', use_bias = False, kernel_regularizer=regularizers.l2(0.0001))(x)
policy_head = layers.Flatten()(policy_head)
policy_head = layers.Activation('softmax', name='policy')(policy_head)
value_head = layers.GlobalAveragePooling2D()(x)
value_head = layers.Dense(50, activation='swish', kernel_regularizer=regularizers.l2(0.0001))(value_head)
value_head = layers.Dense(1, activation='sigmoid', name='value', kernel_regularizer=regularizers.l2(0.0001))(value_head)

model = keras.Model(inputs=input, outputs=[policy_head, value_head])

model.summary ()

model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.005, momentum=0.9),
              loss={'policy': 'categorical_crossentropy', 'value': 'binary_crossentropy'},
              loss_weights={'policy' : 1.0, 'value' : 1.0},
              metrics={'policy': 'categorical_accuracy', 'value': 'mse'})

for i in range (1, epochs + 1):
    print ('epoch ' + str (i))
    golois.getBatch(input_data, policy, value, end, groups, i * N)
    history = model.fit(input_data,
                        {'policy': policy, 'value': value}, 
                        epochs=1, batch_size=batch)
    if (i % 5 == 0):
        gc.collect ()
    if (i % 10 == 0):
        golois.getValidation (input_data, policy, value, end)
        val = model.evaluate (input_data,
                              [policy, value], verbose = 0, batch_size=batch)
        print ("val =", val)
        model.save ('test.h5')
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  board (InputLayer)             [(None, 19, 19, 31)  0           []
#                                 ]
#
#  conv2d (Conv2D)                (None, 19, 19, 32)   8960        ['board[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 19, 19, 32)   9248        ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 19, 19, 32)   9248        ['conv2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 19, 19, 32)   9248        ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 19, 19, 32)   9248        ['conv2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 19, 19, 32)   9248        ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 19, 19, 1)    32          ['conv2d_5[0][0]']
#
#  global_average_pooling2d (Glob  (None, 32)          0           ['conv2d_5[0][0]']
#  alAveragePooling2D)
#
#  flatten (Flatten)              (None, 361)          0           ['conv2d_6[0][0]']
#
#  dense (Dense)                  (None, 50)           1650        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  policy (Activation)            (None, 361)          0           ['flatten[0][0]']
#
#  value (Dense)                  (None, 1)            51          ['dense[0][0]']
#
# ==================================================================================================
# Total params: 56,933
# Trainable params: 56,933
# Non-trainable params: 0
# __________________________________________________________________________________________________
# epoch 1
# 79/79 [==============================] - 11s 16ms/step - loss: 6.5858 - policy_loss: 5.8887 - value_loss: 0.6928 - policy_categorical_accuracy: 0.0040 - value_mse: 0.1213
# epoch 2
# 79/79 [==============================] - 1s 14ms/step - loss: 6.5815 - policy_loss: 5.8843 - value_loss: 0.6929 - policy_categorical_accuracy: 0.0055 - value_mse: 0.1193
# epoch 3
# 79/79 [==============================] - 1s 14ms/step - loss: 6.5376 - policy_loss: 5.8403 - value_loss: 0.6929 - policy_categorical_accuracy: 0.0088 - value_mse: 0.1204
# epoch 4
# 79/79 [==============================] - 1s 14ms/step - loss: 5.7377 - policy_loss: 5.0395 - value_loss: 0.6938 - policy_categorical_accuracy: 0.0479 - value_mse: 0.1211
# epoch 5
# 79/79 [==============================] - 1s 14ms/step - loss: 4.7886 - policy_loss: 4.0909 - value_loss: 0.6933 - policy_categorical_accuracy: 0.1512 - value_mse: 0.1196
# epoch 6
# 79/79 [==============================] - 1s 15ms/step - loss: 4.5289 - policy_loss: 3.8301 - value_loss: 0.6945 - policy_categorical_accuracy: 0.1745 - value_mse: 0.1187
# epoch 7
# 79/79 [==============================] - 1s 14ms/step - loss: 4.4396 - policy_loss: 3.7416 - value_loss: 0.6937 - policy_categorical_accuracy: 0.1920 - value_mse: 0.1205
# epoch 8
# 79/79 [==============================] - 1s 15ms/step - loss: 4.2841 - policy_loss: 3.5865 - value_loss: 0.6931 - policy_categorical_accuracy: 0.2129 - value_mse: 0.1198
# epoch 9
# 79/79 [==============================] - 1s 14ms/step - loss: 4.1965 - policy_loss: 3.4980 - value_loss: 0.6941 - policy_categorical_accuracy: 0.2287 - value_mse: 0.1195
# epoch 10
# 79/79 [==============================] - 1s 14ms/step - loss: 4.1295 - policy_loss: 3.4307 - value_loss: 0.6944 - policy_categorical_accuracy: 0.2380 - value_mse: 0.1197
# val = [4.072861194610596, 3.3754308223724365, 0.6930848956108093, 0.249099999666214, 0.1200159564614296]
# epoch 11
# 79/79 [==============================] - 1s 14ms/step - loss: 4.0834 - policy_loss: 3.3857 - value_loss: 0.6934 - policy_categorical_accuracy: 0.2514 - value_mse: 0.1213
# epoch 12
# 79/79 [==============================] - 1s 14ms/step - loss: 4.0206 - policy_loss: 3.3227 - value_loss: 0.6936 - policy_categorical_accuracy: 0.2598 - value_mse: 0.1205
# epoch 13
# 79/79 [==============================] - 1s 14ms/step - loss: 3.9747 - policy_loss: 3.2761 - value_loss: 0.6942 - policy_categorical_accuracy: 0.2650 - value_mse: 0.1196
# epoch 14
# 79/79 [==============================] - 1s 14ms/step - loss: 3.9677 - policy_loss: 3.2688 - value_loss: 0.6946 - policy_categorical_accuracy: 0.2696 - value_mse: 0.1184
# epoch 15
# 79/79 [==============================] - 1s 14ms/step - loss: 3.9657 - policy_loss: 3.2658 - value_loss: 0.6956 - policy_categorical_accuracy: 0.2665 - value_mse: 0.1215
# epoch 16
# 79/79 [==============================] - 1s 14ms/step - loss: 3.9097 - policy_loss: 3.2120 - value_loss: 0.6934 - policy_categorical_accuracy: 0.2741 - value_mse: 0.1184
# epoch 17
# 79/79 [==============================] - 1s 14ms/step - loss: 3.9239 - policy_loss: 3.2251 - value_loss: 0.6945 - policy_categorical_accuracy: 0.2727 - value_mse: 0.1191
# epoch 18
# 79/79 [==============================] - 1s 14ms/step - loss: 3.8992 - policy_loss: 3.2010 - value_loss: 0.6939 - policy_categorical_accuracy: 0.2758 - value_mse: 0.1214
# epoch 19
# 79/79 [==============================] - 1s 14ms/step - loss: 3.8825 - policy_loss: 3.1846 - value_loss: 0.6937 - policy_categorical_accuracy: 0.2810 - value_mse: 0.1177
# epoch 20
# 79/79 [==============================] - 1s 14ms/step - loss: 3.8592 - policy_loss: 3.1613 - value_loss: 0.6937 - policy_categorical_accuracy: 0.2844 - value_mse: 0.1209
# val = [3.8461320400238037, 3.148027181625366, 0.6938871741294861, 0.2879999876022339, 0.12041689455509186]

# %% [markdown]
# ## Week 1 - First attempt:
